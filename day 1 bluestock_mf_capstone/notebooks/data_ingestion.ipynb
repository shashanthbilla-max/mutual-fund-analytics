# %%
import pandas as pd
import os

# %%
a=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/01_fund_master.csv")
b=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/02_nav_history.csv")
c=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/03_aum_by_fund_house.csv")
d=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/04_monthly_sip_inflows.csv")
e=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/05_category_inflows.csv")
f=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/06_industry_folio_count.csv")
g=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/07_scheme_performance.csv")
h=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/08_investor_transactions.csv")
i=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/09_portfolio_holdings.csv")
j=pd.read_csv("C:/Users/user/OneDrive/Desktop/bluestock_mf_capstone/data/raw data/10_benchmark_indices.csv")

# %%
a
# Out:
#     amfi_code                fund_house  \
# 0      119551           SBI Mutual Fund
# 1      119552           SBI Mutual Fund
# 2      119598           SBI Mutual Fund
# 3      119599           SBI Mutual Fund
# 4      119120           SBI Mutual Fund
# 5      100016          HDFC Mutual Fund
# 6      125497          HDFC Mutual Fund
# 7      100033          HDFC Mutual Fund
# 8      125498          HDFC Mutual Fund
# 9      100025          HDFC Mutual Fund
# 10     120503       ICICI Prudential MF
# 11     120504       ICICI Prudential MF
# 12     120505       ICICI Prudential MF
# 13     120506       ICICI Prudential MF
# 14     120507       ICICI Prudential MF
# 15     118632           Nippon India MF
# 16     118633           Nippon India MF
# 17     118634           Nippon India MF
# 18     118635           Nippon India MF
# 19     118636           Nippon India MF
# 20     120841         Kotak Mahindra MF
# 21     120842         Kotak Mahindra MF
# ...

# %%
b
# Out:
#        amfi_code        date       nav
# 0         119551  2022-01-03   54.3856
# 1         119551  2022-01-04   54.3474
# 2         119551  2022-01-05   54.6869
# 3         119551  2022-01-06   55.4550
# 4         119551  2022-01-07   55.3692
# ...          ...         ...       ...
# 45995     149324  2026-05-25  292.4810
# 45996     149324  2026-05-26  291.2707
# 45997     149324  2026-05-27  288.8007
# 45998     149324  2026-05-28  280.6873
# 45999     149324  2026-05-29  279.7511
#
# [46000 rows x 3 columns]

# %%
c
# Out:
#           date                fund_house  aum_lakh_crore  aum_crore  \
# 0   2022-03-31           SBI Mutual Fund            6.05     605000
# 1   2022-03-31       ICICI Prudential MF            4.65     465000
# 2   2022-03-31          HDFC Mutual Fund            4.35     435000
# 3   2022-03-31           Nippon India MF            2.70     270000
# 4   2022-03-31         Kotak Mahindra MF            2.70     270000
# ..         ...                       ...             ...        ...
# 85  2025-12-31  Aditya Birla Sun Life MF            4.60     460000
# 86  2025-12-31          Axis Mutual Fund            3.50     350000
# 87  2025-12-31           UTI Mutual Fund            4.10     410000
# 88  2025-12-31            Mirae Asset MF            2.90     290000
# 89  2025-12-31           DSP Mutual Fund            2.30     230000
#
#     num_schemes
# 0           186
# 1           216
# 2           195
# 3           177
# 4           168
# ..          ...
# 85          199
# ...

# %%
d
# Out:
#       month  sip_inflow_crore  active_sip_accounts_crore  \
# 0   2022-01             11517                       4.91
# 1   2022-02             11438                       4.93
# 2   2022-03             12328                       5.09
# 3   2022-04             11863                       5.48
# 4   2022-05             12286                       5.55
# 5   2022-06             12276                       5.60
# 6   2022-07             12140                       5.65
# 7   2022-08             12694                       5.71
# 8   2022-09             12976                       5.80
# 9   2022-10             13040                       5.93
# 10  2022-11             13306                       6.00
# 11  2022-12             13573                       6.05
# 12  2023-01             13856                       6.13
# 13  2023-02             13687                       6.19
# 14  2023-03             14276                       6.32
# ...

# %%
e
# Out:
#        month           category  net_inflow_crore
# 0    2024-04          Large Cap            2413.0
# 1    2024-04            Mid Cap            3897.0
# 2    2024-04          Small Cap            3533.0
# 3    2024-04          Flexi Cap            4947.0
# 4    2024-04    Large & Mid Cap            4214.0
# ..       ...                ...               ...
# 139  2025-03  Sectoral/Thematic            8614.0
# 140  2025-03             Liquid           38681.0
# 141  2025-03     Short Duration            4886.0
# 142  2025-03               Gilt             956.0
# 143  2025-03             Hybrid            2830.0
#
# [144 rows x 3 columns]

# %%
f
# Out:
#       month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0   2022-01               13.26                 9.28               1.86
# 1   2022-04               13.91                 9.74               1.95
# 2   2022-07               13.85                 9.69               1.94
# 3   2022-10               14.12                 9.88               1.98
# 4   2023-01               14.81                10.37               2.07
# 5   2023-04               15.54                10.88               2.18
# 6   2023-07               16.28                11.40               2.28
# 7   2023-10               16.72                11.70               2.34
# 8   2024-01               17.78                12.45               2.49
# 9   2024-04               18.85                13.20               2.64
# 10  2024-07               19.98                13.99               2.80
# 11  2024-10               21.62                15.13               3.03
# ...

# %%
g
# Out:
#     amfi_code                                        scheme_name  \
# 0      119551          SBI Bluechip Fund - Regular Plan - Growth
# 1      119552           SBI Bluechip Fund - Direct Plan - Growth
# 2      119598         SBI Small Cap Fund - Regular Plan - Growth
# 3      119599          SBI Small Cap Fund - Direct Plan - Growth
# 4      119120       SBI Magnum Gilt Fund - Regular Plan - Growth
# 5      100016          HDFC Top 100 Fund - Regular Plan - Growth
# 6      125497           HDFC Top 100 Fund - Direct Plan - Growth
# 7      100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 8      125498  HDFC Mid-Cap Opportunities Fund - Direct - Growth
# 9      100025       HDFC Short Term Debt Fund - Regular - Growth
# 10     120503         ICICI Pru Bluechip Fund - Regular - Growth
# 11     120504          ICICI Pru Bluechip Fund - Direct - Growth
# 12     120505           ICICI Pru Midcap Fund - Regular - Growth
# ...

# %%
h
# Out:
#       investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0       INV003054       2024-01-01     119092              SIP        1834
# 1       INV002952       2024-01-01     148567       Redemption      392882
# 2       INV003420       2024-01-01     118636              SIP         912
# 3       INV003436       2024-01-01     118634              SIP        1102
# 4       INV004691       2024-01-01     119094          Lumpsum        8682
# ...           ...              ...        ...              ...         ...
# 32773   INV003340       2025-05-30     101207          Lumpsum      168029
# 32774   INV001838       2025-05-30     119093              SIP        2175
# 32775   INV000074       2025-05-30     120504              SIP       25998
# 32776   INV002929       2025-05-30     148568              SIP         459
# 32777   INV001852       2025-05-30     118633       Redemption      226721
#
#                 state       city city_tier age_group  gender  \
# ...

# %%
i
# Out:
#      amfi_code stock_symbol                 stock_name       sector  \
# 0       119551    POWERGRID     Power Grid Corporation    Utilities
# 1       119551     HDFCBANK              HDFC Bank Ltd      Banking
# 2       119551       GRASIM      Grasim Industries Ltd  Diversified
# 3       119551      DRREDDY   Dr. Reddy's Laboratories       Pharma
# 4       119551   ASIANPAINT           Asian Paints Ltd       Paints
# ..         ...          ...                        ...          ...
# 317     149324     DIVISLAB        Divi's Laboratories       Pharma
# 318     149324   BHARTIARTL          Bharti Airtel Ltd      Telecom
# 319     149324          TCS  Tata Consultancy Services           IT
# 320     149324   INDUSINDBK          IndusInd Bank Ltd      Banking
# 321     149324         NTPC                   NTPC Ltd    Utilities
#
#      weight_pct  market_value_cr  current_price_inr portfolio_date
# 0         13.85           737.09            6011.08     2025-12-31
# ...

# %%
j
# Out:
#             date   index_name  close_value
# 0     2022-01-03      NIFTY50     17492.79
# 1     2022-01-04      NIFTY50     17689.64
# 2     2022-01-05      NIFTY50     17835.05
# 3     2022-01-06      NIFTY50     17878.51
# 4     2022-01-07      NIFTY50     17759.15
# ...          ...          ...          ...
# 8045  2026-05-25  CRISIL_GILT      2278.26
# 8046  2026-05-26  CRISIL_GILT      2281.42
# 8047  2026-05-27  CRISIL_GILT      2281.30
# 8048  2026-05-28  CRISIL_GILT      2298.35
# 8049  2026-05-29  CRISIL_GILT      2302.79
#
# [8050 rows x 3 columns]

# %%
print(a.shape)
print("--------------------------------------------------------")
print(a.dtypes)
print("--------------------------------------------------------")
print(a.head())
# Out:
# (40, 15)
# --------------------------------------------------------
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
# --------------------------------------------------------
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# ...

# %%
print(a.isnull().sum())
print("--------------------------------------------------------")
print(a.duplicated().sum())
print("--------------------------------------------------------")
print( a.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'fund_manager', 'risk_category', 'sebi_category_code']
# --------------------------------------------------------

# %%
print(b.shape)
print("--------------------------------------------------------")
print(b.dtypes)
print("--------------------------------------------------------")
print(b.head())
# Out:
# (46000, 3)
# --------------------------------------------------------
# amfi_code      int64
# date          object
# nav          float64
# dtype: object
# --------------------------------------------------------
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
print(b.isnull().sum())
print("--------------------------------------------------------")
print(b.duplicated().sum())
print("--------------------------------------------------------")
print( b.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# amfi_code    0
# date         0
# nav          0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['date']
# --------------------------------------------------------

# %%
print(c.shape)
print("--------------------------------------------------------")
print(c.dtypes)
print("--------------------------------------------------------")
print(c.head())
# Out:
# (90, 5)
# --------------------------------------------------------
# date               object
# fund_house         object
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object
# --------------------------------------------------------
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
print(c.isnull().sum())
print("--------------------------------------------------------")
print(c.duplicated().sum())
print("--------------------------------------------------------")
print( c.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# date              0
# fund_house        0
# aum_lakh_crore    0
# aum_crore         0
# num_schemes       0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['date', 'fund_house']
# --------------------------------------------------------

# %%
print(d.shape)
print("--------------------------------------------------------")
print(d.dtypes)
print("--------------------------------------------------------")
print(d.head())
# Out:
# (48, 6)
# --------------------------------------------------------
# month                         object
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object
# --------------------------------------------------------
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# ...

# %%
print(d.isnull().sum())
print("--------------------------------------------------------")
print(d.duplicated().sum())
print("--------------------------------------------------------")
print( d.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['month']
# --------------------------------------------------------

# %%
print(e.shape)
print("--------------------------------------------------------")
print(e.dtypes)
print("--------------------------------------------------------")
print(e.head())
# Out:
# (144, 3)
# --------------------------------------------------------
# month                object
# category             object
# net_inflow_crore    float64
# dtype: object
# --------------------------------------------------------
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
print(e.isnull().sum())
print("--------------------------------------------------------")
print(e.duplicated().sum())
print("--------------------------------------------------------")
print( e.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# month               0
# category            0
# net_inflow_crore    0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['month', 'category']
# --------------------------------------------------------

# %%
print(f.shape)
print("--------------------------------------------------------")
print(f.dtypes)
print("--------------------------------------------------------")
print(f.head())
# Out:
# (21, 6)
# --------------------------------------------------------
# month                   object
# total_folios_crore     float64
# equity_folios_crore    float64
# debt_folios_crore      float64
# hybrid_folios_crore    float64
# others_folios_crore    float64
# dtype: object
# --------------------------------------------------------
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# ...

# %%
print(f.isnull().sum())
print("--------------------------------------------------------")
print(f.duplicated().sum())
print("--------------------------------------------------------")
print( f.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# month                  0
# total_folios_crore     0
# equity_folios_crore    0
# debt_folios_crore      0
# hybrid_folios_crore    0
# others_folios_crore    0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['month']
# --------------------------------------------------------

# %%
print(g.shape)
print("--------------------------------------------------------")
print(g.dtypes)
print("--------------------------------------------------------")
print(g.head())
# Out:
# (40, 19)
# --------------------------------------------------------
# amfi_code               int64
# scheme_name            object
# fund_house             object
# category               object
# plan                   object
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade             object
# dtype: object
# --------------------------------------------------------
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# ...

# %%
print(g.isnull().sum())
print("--------------------------------------------------------")
print(g.duplicated().sum())
print("--------------------------------------------------------")
print( g.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# amfi_code             0
# scheme_name           0
# fund_house            0
# category              0
# plan                  0
# return_1yr_pct        0
# return_3yr_pct        0
# return_5yr_pct        0
# benchmark_3yr_pct     0
# alpha                 0
# beta                  0
# sharpe_ratio          0
# sortino_ratio         0
# std_dev_ann_pct       0
# max_drawdown_pct      0
# aum_crore             0
# expense_ratio_pct     0
# morningstar_rating    0
# risk_grade            0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['scheme_name', 'fund_house', 'category', 'plan', 'risk_grade']
# --------------------------------------------------------

# %%
print(i.shape)
print("--------------------------------------------------------")
print(i.dtypes)
print("--------------------------------------------------------")
print(i.head())
# Out:
# (322, 8)
# --------------------------------------------------------
# amfi_code              int64
# stock_symbol          object
# stock_name            object
# sector                object
# weight_pct           float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date        object
# dtype: object
# --------------------------------------------------------
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# ...

# %%
print(i.isnull().sum())
print("--------------------------------------------------------")
print(i.duplicated().sum())
print("--------------------------------------------------------")
print( i.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# amfi_code            0
# stock_symbol         0
# stock_name           0
# sector               0
# weight_pct           0
# market_value_cr      0
# current_price_inr    0
# portfolio_date       0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['stock_symbol', 'stock_name', 'sector', 'portfolio_date']
# --------------------------------------------------------

# %%
print(j.shape)
print("--------------------------------------------------------")
print(j.dtypes)
print("--------------------------------------------------------")
print(j.head())
# Out:
# (8050, 3)
# --------------------------------------------------------
# date            object
# index_name      object
# close_value    float64
# dtype: object
# --------------------------------------------------------
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
print(j.isnull().sum())
print("--------------------------------------------------------")
print(j.duplicated().sum())
print("--------------------------------------------------------")
print( j.select_dtypes(include="object").columns.tolist())
print("--------------------------------------------------------")
# Out:
# date           0
# index_name     0
# close_value    0
# dtype: int64
# --------------------------------------------------------
# 0
# --------------------------------------------------------
# ['date', 'index_name']
# --------------------------------------------------------
